# %% [markdown]
# <div style="text-align: center;">
#
# <img src="LMS Logo (1).png" alt="TIET Logo" style="width: 200px;">
#
# #### Thapar Institute of Engineering and Technology, Patiala <br><br> Computer Science & Engineering Department
# #### ***UCS420: Cognitive Computing <br> <br> Lab Assignment-7***
# #### *Submitted by Smarth Kaushal [Roll No. 102497023] to Dr. Vaishali*
# ---
#
# </div>

# %% [markdown]
# <div style="text-align: center;">
#
# #### <span style="color: green; font-weight: bold;">"Data is like a puzzle—analyzing it is how we uncover the bigger picture."</span>
# </div>
#
# **Q1. You are a data analyst at an e-commerce company. Your task is to analyze sales data, clean and process it, perform statistical analysis, and generate visual insights to help the business make informed decisions. Use your roll number as the random seed to generate unique data for each student.**
#
# **<span style = "color: blue; font-weight:bold;">Part I: Randomized Sales Data Generation (NumPy)</span>**
# 1. Initialize Random Seed.
# 2. Generate Sales Data:
# - Create a NumPy array of random sales data for 12 months (shape = (12, 4)), where each column represents a product category:
#   Electronics, Clothing, Home & Kitchen, Sports.
# - Sales values should be between 1000 and 5000 units per month.
# - The range should be randomized using the seed.
# 3. Convert to DataFrame -- Convert the cleaned NumPy array into a Pandas DataFrame with:
#   - Columns: Electronics, Clothing, Home & Kitchen, Sports.
#   - Index: Months from Jan to Dec.
#
# **<span style = "color: blue; font-weight:bold;">Part II: Data Manipulation and Analysis (Pandas)</span>**
#
# 1. Display the first 5 rows and summary statistics of the DataFrame.
# 2. Calculate the total sales per category and total sales per month.
# 3. Calculate the average sales growth between consecutive months for each category.
# 4. Add the following columns to the DataFrame:
# - Total Sales: Sum of all categories per month.
# - Growth Rate: Percentage change in Total Sales from the previous month.
# 5. Apply a randomized discount:
# - If your roll number is even, apply a 10% discount to the Electronics category.
# - If odd, apply a 15% discount to the Clothing category.
#
# **<span style = "color: blue; font-weight:bold;">Part III: Visualizations (Matplotlib and Seaborn)</span>**
# 1. Plot monthly sales trends for each category using line plots.
# 2. Create the following plots:
# - Box plots to show the sales distribution for each category.

# %% [markdown]
# #### <span style="color:purple; font-weight:bold;">Step-1. Importing Required Libraries</span>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
roll_number = int(input("Enter your roll number as seed: "))
# Out:
# Enter your roll number as seed:  102497023

# %% [markdown]
# #### <span style="color:purple; font-weight:bold;">Step-2. Generating the dataset: sales_data</span>

# %%
np.random.seed(roll_number) # setting random seed

# Generate a 12x4 matrix (12 months and 4 categories)
sales_data = np.random.randint(1000,5000, size = (12,4))

# %%
# Convert to Pandas DataFrame
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
categories = ['Electronics','Clothing','Home & Kitchen','Sports']

df = pd.DataFrame(sales_data, columns = categories, index = months)
print('Initial sales_data: ')
df.head()
# Out:
# Initial sales_data:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         1333      4902            1333    3642
# Feb         1035      4223            1754    2660
# Mar         2497      4911            2346    3017
# Apr         4101      4865            2994    1909
# May         3905      4269            1806    3946

# %% [markdown]
# <div style="text-align:center;">
#
# #### <span style="color: green; font-weight:bold;">Exploratory Data Analysis (EDA)</span>
#
# </div>

# %% [markdown]
# #### <span style="color:purple; font-weight:bold;">Step-3. Data Understanding and Cleaning</span>

# %% [markdown]
# #### 3.1 First 5 Records of the data

# %%
df.head()
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         1333      4902            1333    3642
# Feb         1035      4223            1754    2660
# Mar         2497      4911            2346    3017
# Apr         4101      4865            2994    1909
# May         3905      4269            1806    3946

# %% [markdown]
# #### 3.2 Checking the Numerical and Categorical features

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 4 numerical features : ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports']
#
# We have 0 categorical features : []

# %% [markdown]
# #### 3.3 Checking the datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, Jan to Dec
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Electronics     12 non-null     int32
#  1   Clothing        12 non-null     int32
#  2   Home & Kitchen  12 non-null     int32
#  3   Sports          12 non-null     int32
# dtypes: int32(4)
# memory usage: 288.0+ bytes

# %% [markdown]
# #### 3.4 Checking for Missing Values

# %%
df.isna().sum()
# Out:
# Electronics       0
# Clothing          0
# Home & Kitchen    0
# Sports            0
# dtype: int64

# %% [markdown]
# The dataset doesnot contain any missing values, so no imputation is required.

# %% [markdown]
# #### 3.5 Checking for Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values in the dataset.

# %% [markdown]
# #### 3.6 Basic Statistics Summary of the dataset

# %%
print('Summary Statistics: ')
df.describe()
# Out:
# Summary Statistics:
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   2757.250000  3424.166667     2632.833333  3336.333333
# std    1301.238719  1351.618682      921.248543   828.168882
# min    1035.000000  1113.000000     1333.000000  1909.000000
# 25%    1692.250000  2339.750000     1870.500000  2648.750000
# 50%    2496.500000  3621.500000     2620.000000  3448.500000
# 75%    3970.500000  4661.000000     3058.000000  3868.750000
# max    4474.000000  4911.000000     4645.000000  4556.000000

# %% [markdown]
# #### 3.7 Outlier Detection through Boxplot

# %%
# Box Plot - Sales Distribution
plt.figure(figsize=(8,5))
sns.boxplot(data=df[categories])
plt.title("Sales Distribution Per Category")
plt.show()

# %% [markdown]
# There are no outliers in the data.

# %% [markdown]
# #### <span style="color:coral; font-weight:bold;">Data Cleaning Status: No missing values, duplicate values or errors detected. Hence, no imputation required.</span>

# %% [markdown]
# #### <span style="color:purple; font-weight:bold;">Step-4. Data Preprocessing and Transformation</span>

# %% [markdown]
# #### 4.1 Calculating total sales per category

# %%
total_sales_per_category = df[categories].sum()
print("Total sales per category: \n", total_sales_per_category)
# Out:
# Total sales per category:
#  Electronics       33087
# Clothing          41090
# Home & Kitchen    31594
# Sports            40036
# dtype: int64

# %% [markdown]
# #### 4.2 Calculating total sales per month and adding it as a new column in the DataFrame

# %%
df["Total Sales"] = df.sum(axis=1)
print("Total Sales per Month:\n", df["Total Sales"])
# Out:
# Total Sales per Month:
#  Jan    11210
# Feb     9672
# Mar    12771
# Apr    13869
# May    13926
# Jun    13667
# Jul    10390
# Aug     8909
# Sep    10439
# Oct    14593
# Nov    13305
# Dec    13056
# Name: Total Sales, dtype: int64

# %% [markdown]
# #### 4.3 Calculating Average Sales Growth between consecutive months and adding it as a new feature 'Growth Rate' to the DataFrame

# %%
df["Growth Rate"] = df["Total Sales"].pct_change() * 100
df["Growth Rate"].fillna(0, inplace=True)  # Fill NaN with 0

# %% [markdown]
# #### 4.4 Applying Randomized discount

# %%
# Apply Randomized Discount
if roll_number % 2 == 0:
    df["Electronics"] *= 0.90  # 10% discount
else:
    df["Clothing"] *= 0.85  # 15% discount

# %%
print("Data After Discount:")
df.head()
# Out:
# Data After Discount:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         1333   4166.70            1333    3642        11210     0.000000
# Feb         1035   3589.55            1754    2660         9672   -13.719893
# Mar         2497   4174.35            2346    3017        12771    32.040943
# Apr         4101   4135.25            2994    1909        13869     8.597604
# May         3905   3628.65            1806    3946        13926     0.410989

# %% [markdown]
# #### <span style="color:purple; font-weight:bold;">Step-5. Data Visualization and Analysis</span>

# %% [markdown]
# #### 5.1 Sales Trend Analysis

# %%
sns.set_style("darkgrid")

# Line Plot - Monthly Sales Trend
plt.figure(figsize=(10,5))
sns.lineplot(data=df[categories], marker="o")
plt.title("Monthly Sales Trend")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.legend(categories)
plt.show()

# %% [markdown]
# #### Key Insights from the Monthly Sales Trend Analysis
# The **Monthly Sales Trend** analysis provides valuable insights into sales patterns, enabling data-driven business decisions.
#
# #### Overall Sales Trends
# - **Fluctuations & Seasonality:** All categories show significant sales variations, indicating external influences and seasonal demand.
# - **Peak vs. Low Periods:** Certain months exhibit strong sales peaks, while others experience declines, requiring targeted strategies.
#
# #### Category-Specific Insights
#
# - **Electronics:** High variability, peaking in **January, June, and December**, with a sharp decline in **February** (post-holiday slump).
# - **Clothing:** Sales rise from **April to August**, peak in **July**, and decline in **fall months** due to seasonal fashion trends.
# - **Home & Kitchen:** Maintains **stable sales**, with moderate peaks in **April and October** and fewer fluctuations.
# - **Sports:** Seasonal peaks in **March and October**, with lower demand during **winter months**.
#
# #### Conclusion
# The analysis highlights **October-November as a crucial sales period**, while proactive planning for **seasonal fluctuations** can enhance profitability.

# %%
# Box Plot - Sales Distribution
plt.figure(figsize=(8,5))
sns.boxplot(data=df[categories])
plt.title("Sales Distribution Per Category")
plt.show()
plt.savefig('Sales Distribution per Category.png')

# %% [markdown]
# The box plot provides a comparative view of sales distribution across product categories, highlighting key trends and variability.
#
# #### Key Insights
#
# - **Clothing** has the **highest median sales** with a wide **interquartile range (IQR)**, indicating strong but fluctuating demand.
# - **Sports** also shows high median sales but with **lower variability**, suggesting more stable demand.
# - **Electronics & Home & Kitchen** exhibit **lower median sales** with a **narrow IQR**, reflecting steady but moderate performance.
# - **No outliers detected**, confirming consistent sales patterns across all categories.
#
# #### Conclusion
#
# **Clothing and Sports** drive higher sales, while **Electronics and Home & Kitchen** show stable but lower performance. These insights guide **strategic pricing, inventory, and promotional decisions** to optimize revenue.

# %%
plt.figure(figsize=(8, 5))
ax = sns.barplot(x=df.index, y=df["Total Sales"], palette="coolwarm")

for i, bar in enumerate(ax.patches):
    ax.text(bar.get_x() + bar.get_width() / 2,  # X-position → Bar ka center
            bar.get_height() + 100,             # Y-position → Bar ke thoda upar
            f"{int(bar.get_height())}",         # Sales value as label
            ha='center', va='bottom', fontsize=12, color='black', fontweight='bold')

plt.xlabel('Months')
plt.ylabel('Total Sales')
plt.title('Monthly Total_Sales Comparison')
plt.show()
plt.savefig('Total_sales barplot.png')

# %%
best_month = df["Total Sales"].idxmax()
worst_month = df["Total Sales"].idxmin()

print(f"Best Sales Month: {best_month} with {df.loc[best_month, 'Total Sales']} sales.")
print(f"Worst Sales Month: {worst_month} with {df.loc[worst_month, 'Total Sales']} sales.")
# Out:
# Best Sales Month: Oct with 14593 sales.
# Worst Sales Month: Aug with 8909 sales.

# %% [markdown]
# #### Monthly Total Sales Comparison: Key Insights
#
# #### 1. Peak and Low Sales Months
# - **Highest Sales:** **October (14,593)**, likely driven by seasonal demand, festivals, or promotional campaigns.
# - **Lowest Sales:** **August (8,909)**, indicating a period of reduced consumer activity.
#
# #### 2. Q4 Surge (Oct–Dec) Drives Revenue Growth
# - Sales remain **consistently high** from **October to December**, reinforcing the importance of Q4 for revenue.
# - **November and December** maintain strong performance, despite a slight decline from October.
#
# #### 3. Mid-Year Sales Slump (June–August)
# - **Sales decline from June to August**, with August recording the lowest figures.
# - This could indicate a **seasonal slowdown**, requiring targeted marketing efforts to boost demand.
#
# #### 4. Post-Holiday Recovery & Early-Year Trends
# - **February sees a dip (9,672),** but sales rebound strongly in **March (12,771)** and remain stable until May.
# - The **first half of the year** shows moderate fluctuations, with a mix of growth and minor declines.
#
# #### Conclusion
# The data confirms **Q4 as the most profitable period**, emphasizing the need for strong year-end strategies. **August represents the weakest sales period**, requiring interventions to sustain revenue. Understanding these trends allows for **optimized sales planning and strategic decision-making.**

# %% [markdown]
# #### 5.2 Feature Distribution Analysis

# %%
# Distribution Check (Histogram & KDE)
plt.figure(figsize=(10,5))
sns.histplot(df["Total Sales"], kde = True, bins = 10)
plt.title("Distribution of Total Monthly Sales")
plt.xlabel("Total Sales")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### Distribution of Total Monthly Sales: Key Insights
#
# #### Sales Distribution & Frequency:
# - Sales range between **8,909 and 14,593**, indicating moderate variability.
# - The majority of sales fall between **13,000 and 14,500**, suggesting consistently strong performance.
# - Lower sales values (**8,909–10,500**) are less frequent, indicating fewer low-revenue months.
#
# #### Pattern & Distribution Characteristics:
# - **Right-skewed distribution**, with higher sales values being more common.
# - **Bimodal trend** suggests two distinct sales patterns, potentially influenced by seasonality or market cycles.
# - Sales do not follow a normal distribution, reflecting fluctuating demand.
#
# #### Conclusion
# Sales distribution indicates a well-performing business with **seasonal variations** and **distinct demand cycles**.

# %% [markdown]
# #### 5.3 Correlation Analysis

# %%
# Correlation Heatmap
plt.figure(figsize = (8,5))
sns.heatmap(df.corr(), annot = True, cmap = "coolwarm", linewidths = 0.5)
plt.title("Sales Correlation Heatmap")
plt.show()

# %% [markdown]
# The correlation heatmap reveals the strength and direction of relationships between sales categories and overall business performance.
#
# #### Major Observations:
#
# - **Electronics drives Total Sales (0.72 correlation)**, making it a key revenue contributor.
# - **Home & Kitchen and Clothing show moderate correlations with Total Sales (0.42 & 0.32, respectively), while Sports has a weak correlation (0.2)**.
# - **Growth Rate correlates moderately with Total Sales (0.53)**, reinforcing the impact of sales on expansion.
# - **Negative Correlations:**
#   - **Clothing vs. Growth Rate (-0.2)** suggests Clothing sales may not drive strong growth.
#   - **Home & Kitchen vs. Clothing (-0.38)** indicates potential category competition.
#
# #### Conclusion:
# Electronics is the dominant driver of sales, while category interactions suggest the need for strategic adjustments. Further analysis can refine marketing and pricing strategies for sustained growth.

# %% [markdown]
# #### <span style="color:blue; font-weight:bold;">Business Implications & Strategic Takeaways</span>
#
# 1️⃣ **Q4 is the most profitable period**, making it essential for businesses to optimize inventory, allocate higher marketing budgets, and leverage holiday promotions to maximize revenue.
#
# 2️⃣ **Sales slow down between June and August**, requiring intervention through targeted discounts, bundling strategies, and loyalty programs to maintain steady revenue.
#
# 3️⃣ **Electronics is the key growth driver (0.72 correlation)**, indicating the need for efficient stock planning, exclusive product launches, and data-driven promotional campaigns.
#
# 4️⃣ **Clothing exhibits high variability**, necessitating agile inventory management, trend-based pricing, and seasonal marketing strategies to capture demand effectively.
#
# 5️⃣ **Home & Kitchen maintains stable demand**, providing an opportunity to boost sales through cross-category bundling and targeted promotions.
#
# 6️⃣ **Sports experiences seasonal spikes in March and October**, requiring businesses to align marketing efforts with fitness trends and major sporting events.
#
# 7️⃣ **Sales distribution patterns highlight seasonal cycles**, emphasizing the need for improved demand forecasting to optimize inventory and prevent stock imbalances.
#
# 8️⃣ **AI-driven marketing and customer segmentation** can enhance engagement and conversions by implementing personalized recommendations and cross-selling strategies.
#
# #### Strategic Takeaway:
# To maximize profitability, businesses should **capitalize on Q4 sales peaks, address mid-year slowdowns, focus on Electronics as a revenue driver, refine demand forecasting for seasonal fluctuations, and leverage AI-powered marketing for better customer targeting and inventory optimization.**

# %% [markdown]
# **Q.2 For the array: array = np.array([[1, -2, 3],[-4, 5, -6]])**
# i. Find element-wise absolute value.
# ii. Find the 25th, 50th, and 75th percentile of flattened array, for each column, for each row.
# iii. Mean, Median and Standard Deviation of flattened array, of each column, and each row.

# %%
import numpy as np

# Define the array
array = np.array([[1, -2, 3], [-4, 5, -6]])

# i. Element-wise absolute value
abs_array = np.abs(array)

# ii. Percentiles (flattened, column-wise, row-wise)
percentiles_flattened  = np.percentile(array, [25, 50, 75])
percentiles_columnwise = np.percentile(array, [25, 50, 75], axis=0)
percentiles_rowwise    = np.percentile(array, [25, 50, 75], axis=1)

# iii. Mean, Median, Standard Deviation (flattened, column-wise, row-wise)
mean_flattened   = np.mean(array)
median_flattened = np.median(array)
std_flattened    = np.std(array)

mean_columnwise   = np.mean(array, axis=0)
median_columnwise = np.median(array, axis=0)
std_columnwise    = np.std(array, axis=0)

mean_rowwise      = np.mean(array, axis=1)
median_rowwise    = np.median(array, axis=1)
std_rowwise       = np.std(array, axis=1)

# Printing results
print("Element-wise Absolute Value:\n", abs_array)
print("\nPercentiles:\n")
print("\nFlattened:\n",   percentiles_flattened)
print("\nColumn-wise:\n", percentiles_columnwise)
print("\nRow-wise:\n",    percentiles_rowwise)
print()
print("Mean    (Flattened):", mean_flattened)
print("Median  (Flattened):", median_flattened)
print("Std_Dev (Flattened):", std_flattened)
print()
print("Mean    (Column-wise):", mean_columnwise)
print("Median  (Column-wise):", median_columnwise)
print("Std_Dev (Column-wise):", std_columnwise)
print()
print("Mean    (Row-wise):", mean_rowwise)
print("Median  (Row-wise):", median_rowwise)
print("Std_Dev (Row-wise):", std_rowwise)
# Out:
# Element-wise Absolute Value:
#  [[1 2 3]
#  [4 5 6]]
#
# Percentiles:
#
#
# Flattened:
#  [-3.5 -0.5  2.5]
#
# Column-wise:
#  [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]]
#
# Row-wise:
#  [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]]
#
# Mean    (Flattened): -0.5
# Median  (Flattened): -0.5
# Std_Dev (Flattened): 3.8622100754188224
#
# Mean    (Column-wise): [-1.5  1.5 -1.5]
# Median  (Column-wise): [-1.5  1.5 -1.5]
# Std_Dev (Column-wise): [2.5 3.5 4.5]
#
# Mean    (Row-wise): [ 0.66666667 -1.66666667]
# Median  (Row-wise): [ 1. -4.]
# Std_Dev (Row-wise): [2.05480467 4.78423336]

# %% [markdown]
# **Q.3 For the array: a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0]). Find floor, ceiling and truncated value, and rounded values.**

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])

print("\nFloor  :", np.floor(a))
print("Ceil   :", np.ceil(a))
print("Trunc  :", np.trunc(a))
print("Round  :", np.round(a))
# Out:
# Floor  : [-2. -2. -1.  0.  1.  1.  3.]
# Ceil   : [-1. -1. -0.  1.  2.  2.  3.]
# Trunc  : [-1. -1. -0.  0.  1.  1.  3.]
# Round  : [-2. -2. -0.  0.  2.  2.  3.]

# %% [markdown]
# **Q.4 WAP to swap two elements in a list in Python Using a Temporary Variable.**

# %%
def swap_list_elements(lst, i, j):
    lst[i], lst[j] = lst[j], lst[i]
    return lst

# Example Usage:
lst = [1, 2, 3, 4, 5]
print("Original List :", lst)
swapped_list = swap_list_elements(lst, 1, 3)  # Swap index 1 and 3
print("Swapped List  :", swapped_list)
# Out:
# Original List : [1, 2, 3, 4, 5]
# Swapped List  : [1, 4, 3, 2, 5]

# %% [markdown]
# **Q.5 Write a Python program to swap two elements in a set by converting it to a list first.**

# %%
def swap_set_elements(s, i, j):
    s = list(s)
    s[i], s[j] = s[j], s[i]
    return set(s)

# Example Usage:
s = {10, 20, 30, 40, 50}
print("Original Set:", s)
swapped_set = swap_set_elements(s, 0, 2)  # Swap first and third element
print("Swapped Set :", swapped_set)
# Out:
# Original Set: {50, 20, 40, 10, 30}
# Swapped Set : {40, 10, 50, 20, 30}
